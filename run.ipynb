# %%
import utilszhu as uz
ticker_symbol = "INTC"
stock_analysis = uz.KeyFinancials(ticker_symbol)

# Enter the ticker symbols of its competetors
stock_analysis.competetors = ['MSFT', 'GOOGL', 'QCOM', 'NVDA', 'AAPL']

# Enter the P/S, P/OCF, P/FCF, P/E in the industry of this company, the order does matter
stock_analysis.industry_average_ratios = [3, 10, 15, 20]

# Enter your assumption for this company's revenue growth in the coming 3 years
revenue_growth_assumption_3y = [0.05, 0.03, 0.03] # 0.1 means 10% revenue growth

# Compare the price history with the best ETF for growth stocks, and the best ETF for dividend stocks
stock_analysis.plot_benchmark_comparisons()
# stock_analysis.plot_return_correlation()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# price_period[0] =  19.867773056030273
# price_period[0] =  58.475284576416016
# price_period[0] =  20.494976043701172
# price_period[0] =  19.867773056030273
# price_period[0] =  58.475284576416016
# price_period[0] =  20.494976043701172
# price_period[0] =  50.946128845214844
# price_period[0] =  399.0885314941406
# price_period[0] =  79.39936828613281

# %%
stock_analysis.get_customized_info_all_stocks()
# Out:
# Loading history info of INTC ......
# Loading history info of MSFT ......
# Loading history info of GOOGL ......
# Loading history info of QCOM ......
# Loading history info of NVDA ......
# Loading history info of AAPL ......
#                             INTC        MSFT       GOOGL       QCOM  \
# Current Price              37.29      260.26     2234.03     130.23
# Market Cap(m)          152478.81  1946492.34  1475826.94  145857.59
# Total Debt(m)           37247.00    77981.00    28602.00   15680.00
# Total Cash(m)           38696.00   104660.00   133970.00   11546.00
# Total Revenue(m)        77704.00   192557.01   270334.00   39264.00
# Operating Cashflow(m)   30534.00    87116.00    97469.00    9205.00
# Free Cashflow(m)         8417.25    48917.00    52881.25    7258.50
# Net Income(m)           24620.00    72456.00    74539.00   11159.00
# Revenue Growth             -0.07        0.18        0.23       0.41
# Quick Ratio                 1.59        1.77        2.74       1.16
# Debt/FCF                    4.43        1.59        0.54       2.16
# P/S                         1.96       10.11        5.46       3.71
# P/OCF                       4.99       22.34       15.14      15.85
# P/FCF                      18.12       39.79       27.91      20.09
# P/E                         6.19       27.17       20.20      13.34
# Net Income/S                0.32        0.38        0.28       0.28
# FCF/OCF                     0.28        0.56        0.54       0.79
# OCF/S                       0.39        0.45        0.36       0.23
#
#                             NVDA        AAPL
# Current Price             155.42      139.23
# Market Cap(m)          387306.65  2253465.32
# Total Debt(m)           11846.00   119981.00
# Total Cash(m)           20338.00    51511.00
# Total Revenue(m)        29541.00   386017.00
# Operating Cashflow(m)    8965.00   116426.00
# Free Cashflow(m)         8018.38    84384.63
# Net Income(m)            9458.00   101935.00
# Revenue Growth              0.46        0.09
# Quick Ratio                 4.63        0.76
# Debt/FCF                    1.48        1.42
# P/S                        13.11        5.84
# P/OCF                      43.20       19.36
# P/FCF                      48.30       26.70
# P/E                        41.68       22.64
# Net Income/S                0.32        0.26
# FCF/OCF                     0.89        0.72
# OCF/S                       0.30        0.30

# %%
stock_analysis.plot_income_statement()
# Out:
# Total Revenue = [70848.0, 71965.0, 77867.0, 79024.0]
# Cost Of Revenue = [27111.0, 29825.0, 34255.0, 35209.0]
# Selling General Administrative = [6950.0, 6350.0, 6180.0, 6543.0]
# Operating Income = [23244.0, 22428.0, 23876.0, 22082.0]
# Net Income Applicable To Common Shares = [21053.0, 21048.0, 20899.0, 19868.0]
#
# Cost of Revenue / Revenue = [0.38, 0.41, 0.44, 0.45]
# OCF / Revenue = [0.33, 0.31, 0.31, 0.28]
# Net Income / Revenue = [0.3, 0.29, 0.27, 0.25]

# %%
stock_analysis.plot_cashflow_statement()
# Out:
# Total Cash From Operating Activities = [29432.0, 33145.0, 35384.0, 29991.0]
# Total Cashflows From Investing Activities = [-11239.0, -14405.0, -20796.0, -25167.0]
# Total Cash From Financing Activities = [-18607.0, -17565.0, -12917.0, -5862.0]
# Capital Expenditures = [-15181.0, -16213.0, -14453.0, -20329.0]
# Free Cashflow = [14251.0, 16932.0, 20931.0, 9662.0]
#
# Revenue growth =  [-0.1, 0.02, 0.08, 0.01]
# OCF to Revenue =  [0.42, 0.46, 0.45, 0.38]
# FCF to Revenue =  [0.2, 0.24, 0.27, 0.12]

# %%
stock_analysis.plot_balance_sheet()
# Out:
# Long Term Debt = [25098.0, 25308.0, 33897.0, 33510.0]
# Total Liab = [53400.0, 59020.0, 72053.0, 73015.0]
# Cash = [3019.0, 4194.0, 5865.0, 4827.0]
# Net Tangible Assets = [38214.0, 40401.0, 45041.0, 61158.0]
# Intangible Assets = [11836.0, 10827.0, 9026.0, 7270.0]
#
# FCF to Long-term Debt =  [0.57, 0.67, 0.62, 0.29]
# Total Cash to Long-term Debt =  [0.57, 0.67, 0.62, 0.29]

# %%
stock_analysis.history_info.major_holders.reset_index()
# Out:
#    index       0                                      1
# 0      0   0.06%        % of Shares Held by All Insider
# 1      1  63.80%       % of Shares Held by Institutions
# 2      2  63.84%        % of Float Held by Institutions
# 3      3    3631  Number of Institutions Holding Shares

# %%
# Valuation

stock_analysis.calculate3y_value_relative(revenue_growth_assumption_3y) # Revenue growth rate, 0.5 means 50% YoY revenue growth
# Out:
# Note that the predicted price (3-year) assumes that the number of shares outstanding stays the same as the current value!
# Current Revenue =  77704.0
# Revenue after  1  year =  81589.2
# Revenue after  2  year =  84036.876
# Revenue after  3  year =  86557.98228000001
# Current market cap =  152478.81
#                            Price based on MSFT  Price based on GOOGL  \
# Current Price of INTC                    37.29                 37.29
# Valuation using P/S                     192.35                103.88
# Valuation using P/OCF                   166.95                113.14
# Valuation using P/FCF                    81.89                 57.44
# Valuation using P/E                     163.68                121.69
# Valuation in 3-years(P/S)               214.01                115.58
#
#                            Price based on QCOM  Price based on NVDA  \
# Current Price of INTC                    37.29                37.29
# Valuation using P/S                      70.58               249.42
# Valuation using P/OCF                   118.45               322.83
# Valuation using P/FCF                    41.34                99.40
# Valuation using P/E                      80.36               251.09
# Valuation in 3-years(P/S)                78.54               277.52
#
#                            Price based on AAPL  \
# Current Price of INTC                    37.29
# Valuation using P/S                     111.11
# Valuation using P/OCF                   144.68
# Valuation using P/FCF                    54.95
# Valuation using P/E                     136.39
# Valuation in 3-years(P/S)               123.62
#
#                            Price based on industry average
# Current Price of INTC                                37.29
# Valuation using P/S                                  57.08
# Valuation using P/OCF                                74.73
# Valuation using P/FCF                                30.87
# Valuation using P/E                                 120.48
# Valuation in 3-years(P/S)                            63.51

# %%
stock_analysis.plot_shares()
# Out:
# Outstanding Shares in millions =  [4611.0, 4417.0, 4199.0, 4059.0]
# Shares change in percentage =  [0.14, -0.04, -0.05, -0.03]

# %%
# recommendation
stock_analysis.history_info.recommendations.reset_index().tail(20).iloc[: , :4]
# Out:
#                    Date                       Firm        To Grade  \
# 382 2021-10-22 10:14:05                        UBS         Neutral
# 383 2021-10-22 10:30:43             Morgan Stanley    Equal-Weight
# 384 2021-10-22 10:33:33                     Mizuho         Neutral
# 385 2021-10-22 11:50:36                    Needham             Buy
# 386 2021-10-26 10:10:42                BMO Capital  Market Perform
# 387 2022-01-04 13:40:19          Tigress Financial             Buy
# 388 2022-01-05 12:39:14  Northland Capital Markets      Outperform
# 389 2022-01-11 09:31:45                    Keybanc   Sector Weight
# 390 2022-01-18 13:31:14                  Citigroup         Neutral
# 391 2022-01-27 12:30:47                     Mizuho         Neutral
# 392 2022-01-27 13:43:56              Credit Suisse      Outperform
# 393 2022-01-27 15:27:50                        UBS         Neutral
# 394 2022-02-18 14:15:38                   Barclays     Underweight
# 395 2022-02-18 14:37:50                BMO Capital  Market Perform
# 396 2022-02-23 10:26:16              Raymond James  Market Perform
# 397 2022-03-03 11:13:10             Morgan Stanley     Underweight
# 398 2022-04-29 10:55:30                    Needham             Buy
# 399 2022-04-29 12:39:41                Wells Fargo    Equal-Weight
# 400 2022-06-06 11:12:28                  Citigroup         Neutral
# 401 2022-06-29 12:02:06          B of A Securities    Underperform
#
#          From Grade
# 382             Buy
# 383      Overweight
# 384             Buy
# 385
# 386      Outperform
# 387
# 388  Market Perform
# 389      Overweight
# 390
# 391
# 392
# 393
# 394
# 395
# 396    Underperform
# 397    Equal-Weight
# 398
# 399
# 400
# 401
